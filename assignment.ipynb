# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('API_19_DS2_en_csv_v2_4902199.csv', skiprows=4)

# %%
df.head(5)
# Out:
#   Country Name Country Code                            Indicator Name  \
# 0        Aruba          ABW  Urban population (% of total population)
# 1        Aruba          ABW                          Urban population
# 2        Aruba          ABW        Urban population growth (annual %)
# 3        Aruba          ABW                         Population, total
# 4        Aruba          ABW              Population growth (annual %)
#
#       Indicator Code       1960          1961          1962          1963  \
# 0  SP.URB.TOTL.IN.ZS     50.776     50.761000     50.746000     50.730000
# 1        SP.URB.TOTL  27728.000  28330.000000  28764.000000  29157.000000
# 2        SP.URB.GROW        NaN      2.147858      1.520329      1.357042
# 3        SP.POP.TOTL  54608.000  55811.000000  56682.000000  57475.000000
# 4        SP.POP.GROW        NaN      2.179059      1.548572      1.389337
#
#            1964          1965  ...           2013           2014  \
# ...

# %%
countries = ['United States', 'United Kingdom', 'France', 'India', 'China',
             'Germany', 'Russian Federation', ]
new_df = df.loc[df['Country Name'].isin(countries)]
indicator = ['SP.URB.TOTL', 'SP.POP.TOTL', 'SH.DYN.MORT', 'SH.DYN.MORT', 'ER.H2O.FWTL.K3', 'EN.ATM.GHGT.KT.CE', 'EN.ATM.CO2E.KT',
'EN.ATM.CO2E.SF.KT', 'EN.ATM.CO2E.LF.KT', 'EN.ATM.CO2E.GF.KT', 'EG.USE.ELEC.KH.PC', 'EG.ELC.RNEW.ZS', 'AG.LND.FRST.K2', 'AG.LND.ARBL.ZS',
'AG.LND.AGRI.K2']
new_df = new_df.loc[df['Indicator Code'].isin(indicator)]

# %%
new_df = new_df.reset_index(drop=True)
new_df.head(5)
# Out:
#   Country Name Country Code  \
# 0        China          CHN
# 1        China          CHN
# 2        China          CHN
# 3        China          CHN
# 4        China          CHN
#
#                                       Indicator Name     Indicator Code  \
# 0                                   Urban population        SP.URB.TOTL
# 1                                  Population, total        SP.POP.TOTL
# 2    Mortality rate, under-5 (per 1,000 live births)        SH.DYN.MORT
# 3  Annual freshwater withdrawals, total (billion ...     ER.H2O.FWTL.K3
# 4  Total greenhouse gas emissions (kt of CO2 equi...  EN.ATM.GHGT.KT.CE
#
#           1960         1961         1962         1963         1964  \
# 0  108085352.0  110327936.0  114685540.0  121162226.0  127791981.0
# 1  667070000.0  660330000.0  665770000.0  682335000.0  698355000.0
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# ...

# %%
new_df.drop('Country Code', axis=1, inplace=True)

# %%
new_df.head(5)
# Out:
#   Country Name                            Indicator Name     Indicator Code  \
# 0        China  Urban population (% of total population)  SP.URB.TOTL.IN.ZS
# 1        China                          Urban population        SP.URB.TOTL
# 2        China        Urban population growth (annual %)        SP.URB.GROW
# 3        China                         Population, total        SP.POP.TOTL
# 4        China              Population growth (annual %)        SP.POP.GROW
#
#            1960          1961          1962          1963          1964  \
# 0  1.620300e+01  1.670800e+01  1.722600e+01  1.775700e+01  1.829900e+01
# 1  1.080854e+08  1.103279e+08  1.146855e+08  1.211622e+08  1.277920e+08
# 2           NaN  2.053596e+00  3.873678e+00  5.493641e+00  5.327344e+00
# 3  6.670700e+08  6.603300e+08  6.657700e+08  6.823350e+08  6.983550e+08
# 4           NaN -1.015528e+00  8.204555e-01  2.457647e+00  2.320683e+00
#
# ...

# %%
new_df.to_csv('Output.csv')
